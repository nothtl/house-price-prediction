# %%
import pandas as pd
from fastai.tabular.all import *

# Load your already cleaned/train DataFrame (use what you had with SalePrice, Id, etc)
df = pd.read_csv("../../data/train.csv")

# Optionally: use your earlier data cleaning code here to match your best results!

# Set which columns are categorical and which are continuous:
cat_names = df.select_dtypes("object").columns.tolist()
cont_names = [c for c in df.columns if c not in cat_names + ["SalePrice", "Id"]]

# We'll predict the log of SalePrice
df["LogSalePrice"] = np.log1p(df["SalePrice"])

# %%
cat_names = df.select_dtypes("object").columns.tolist()
cont_names = df.select_dtypes(["float64", "int64"]).columns.tolist()
cont_names = [c for c in cont_names if c not in ["SalePrice", "Id"]]

# %%
# fastai needs to know which is the dependent variable (y), and validation set
splits = RandomSplitter(valid_pct=0.2, seed=42)(range_of(df))

to = TabularPandas(
    df,
    procs=[Categorify, FillMissing, Normalize],
    cat_names=cat_names,
    cont_names=cont_names,
    y_names="LogSalePrice",
    splits=splits,
)

dls = to.dataloaders(bs=64)
# Out:
# d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fastai\tabular\core.py:314: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   to[n].fillna(self.na_dict[n], inplace=True)
# d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fastai\tabular\core.py:314: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   to[n].fillna(self.na_dict[n], inplace=True)
# d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fastai\tabular\core.py:314: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   to[n].fillna(self.na_dict[n], inplace=True)

# %%
learn = tabular_learner(dls, metrics=rmse)
learn.fit_one_cycle(50)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>_rmse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.897553</td>
#       <td>0.824627</td>
#       <td>0.908090</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.604734</td>
#       <td>0.273307</td>
#       <td>0.522788</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.430150</td>
#       <td>0.152347</td>
#       <td>0.390317</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.334912</td>
#       <td>0.130062</td>
#       <td>0.360641</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.263094</td>
#       <td>0.094071</td>
#       <td>0.306710</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.201002</td>
#       <td>0.086901</td>
#       <td>0.294790</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.160398</td>
#       <td>0.078674</td>
#       <td>0.280488</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.127139</td>
#       <td>0.057198</td>
#       <td>0.239162</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.106759</td>
#       <td>0.052729</td>
#       <td>0.229629</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.093485</td>
#       <td>0.062975</td>
#       <td>0.250949</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.078768</td>
#       <td>0.041232</td>
#       <td>0.203056</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.070230</td>
#       <td>0.042751</td>
#       <td>0.206764</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.063589</td>
#       <td>0.033042</td>
#       <td>0.181776</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.057596</td>
#       <td>0.032912</td>
#       <td>0.181416</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.050319</td>
#       <td>0.034266</td>
#       <td>0.185110</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.051656</td>
#       <td>0.043259</td>
#       <td>0.207988</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.049088</td>
#       <td>0.034855</td>
#       <td>0.186694</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.047034</td>
#       <td>0.025378</td>
#       <td>0.159303</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.046821</td>
#       <td>0.028284</td>
#       <td>0.168177</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.042184</td>
#       <td>0.026380</td>
#       <td>0.162420</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.042400</td>
#       <td>0.021355</td>
#       <td>0.146134</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.041178</td>
#       <td>0.027817</td>
#       <td>0.166783</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.041926</td>
#       <td>0.024743</td>
#       <td>0.157298</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.037982</td>
#       <td>0.035328</td>
#       <td>0.187957</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.036429</td>
#       <td>0.034075</td>
#       <td>0.184594</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.031022</td>
#       <td>0.022874</td>
#       <td>0.151243</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.028774</td>
#       <td>0.021852</td>
#       <td>0.147824</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.026492</td>
#       <td>0.020444</td>
#       <td>0.142983</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.027620</td>
#       <td>0.021841</td>
#       <td>0.147786</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.029155</td>
#       <td>0.019273</td>
#       <td>0.138827</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.028673</td>
#       <td>0.023633</td>
#       <td>0.153731</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.027858</td>
#       <td>0.019537</td>
#       <td>0.139774</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.026758</td>
#       <td>0.021978</td>
#       <td>0.148248</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.031133</td>
#       <td>0.028193</td>
#       <td>0.167907</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.030554</td>
#       <td>0.020672</td>
#       <td>0.143778</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.029319</td>
#       <td>0.033119</td>
#       <td>0.181987</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.033624</td>
#       <td>0.019408</td>
#       <td>0.139314</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.030409</td>
#       <td>0.023066</td>
#       <td>0.151875</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.029849</td>
#       <td>0.017966</td>
#       <td>0.134039</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.026920</td>
#       <td>0.022698</td>
#       <td>0.150657</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.028009</td>
#       <td>0.018709</td>
#       <td>0.136780</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.025432</td>
#       <td>0.019043</td>
#       <td>0.137996</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.024154</td>
#       <td>0.021212</td>
#       <td>0.145642</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.025525</td>
#       <td>0.020966</td>
#       <td>0.144798</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.024072</td>
#       <td>0.022998</td>
#       <td>0.151652</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.022415</td>
#       <td>0.019914</td>
#       <td>0.141118</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.021370</td>
#       <td>0.023997</td>
#       <td>0.154910</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.022535</td>
#       <td>0.018638</td>
#       <td>0.136519</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.025243</td>
#       <td>0.026497</td>
#       <td>0.162780</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.024945</td>
#       <td>0.025613</td>
#       <td>0.160040</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Predict on validation set
preds, targs = learn.get_preds()
val_rmse = rmse(preds, targs)
print(f"Validation RMSE: {float(val_rmse):.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Validation RMSE: 0.1600

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error

# 1. Validation set from fastai TabularPandas
valid_idx = to.splits[1]
df_valid = to.items.iloc[valid_idx].copy()
X_valid = df_valid[dls.x_names]
y_valid = df_valid["LogSalePrice"]

# 2. Baseline RMSE
dl = learn.dls.test_dl(X_valid)
preds, _ = learn.get_preds(dl=dl)
base_rmse = mean_squared_error(y_valid, preds.numpy(), squared=False)

# 3. Permutation importance
importances = []
for col in X_valid.columns:
    X_shuff = X_valid.copy()
    X_shuff[col] = np.random.permutation(X_shuff[col])
    dl_shuff = learn.dls.test_dl(X_shuff)
    preds_shuff, _ = learn.get_preds(dl=dl_shuff)
    rmse = mean_squared_error(y_valid, preds_shuff.numpy(), squared=False)
    importances.append(rmse - base_rmse)

feat_imp = pd.Series(importances, index=X_valid.columns).sort_values(ascending=False)
feat_imp.plot(
    kind="barh",
    title="Permutation Feature Importance (fastai tabular NN)",
    figsize=(8, 5),
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 6
#       3 from sklearn.metrics import mean_squared_error
#       5 # 1. Validation set from fastai TabularPandas
# ----> 6 valid_idx = to.splits[1]
#       7 df_valid = to.items.iloc[valid_idx].copy()
#       8 X_valid = df_valid[dls.x_names]
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fastcore\basics.py:536, in GetAttr.__getattr__(self, k)
#     534 if self._component_attr_filter(k):
#     535     attr = getattr(self,self._default,None)
# --> 536     if attr is not None: return getattr(attr,k)
#     537 raise AttributeError(k)
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fasttransform\transform.py:252, in Pipeline.__getattr__(self, k)
# --> 252 def __getattr__(self,k): return gather_attrs(self, k, 'fs')
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fasttransform\transform.py:213, in gather_attrs(o, k, nm)
#     211 att = getattr(o,nm)
#     212 res = [t for t in att.attrgot(k) if t is not None]
# --> 213 if not res: raise AttributeError(k)
#     214 return res[0] if len(res)==1 else L(res)
#
# AttributeError: splits

# %%
# Load test data
test_df = pd.read_csv("../../data/test.csv")

# Apply same processing as training set
to_test = TabularPandas(
    test_df,
    procs=[Categorify, FillMissing, Normalize],
    cat_names=cat_names,
    cont_names=cont_names,
    y_names=None,
    splits=None,
)
test_dl = to.dataloaders(bs=64)

# Predict
test_preds = learn.get_preds(dl=test_dl)[0].squeeze().numpy()
test_preds_final = np.expm1(test_preds)  # Undo log transform

# Prepare submission
submission = pd.DataFrame({"Id": test_df["Id"], "SalePrice": test_preds_final})
submission.to_csv("submission_fastai.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 5
#       2 test_df = pd.read_csv("../../data/test.csv")
#       4 # Apply same processing as training set
# ----> 5 to_test = TabularPandas(
#       6     test_df,
#       7     procs=[Categorify, FillMissing, Normalize],
#       8     cat_names=cat_names,
#       9     cont_names=cont_names,
#      10     y_names=None,
#      11     splits=None,
#      12 )
#      13 test_dl = to.dataloaders(bs=64)
#      15 # Predict
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fastai\tabular\core.py:170, in Tabular.__init__(self, df, procs, cat_names, cont_names, y_names, y_block, splits, do_setup, device, inplace, reduce_memory)
#     168 self.cat_names,self.cont_names,self.procs = L(cat_names),L(cont_names),Pipeline(procs)
#     169 self.split = len(df) if splits is None else len(splits[0])
# --> 170 if do_setup: self.setup()
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fastai\tabular\core.py:181, in Tabular.setup(self)
# --> 181 def setup(self): self.procs.setup(self)
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fasttransform\transform.py:240, in Pipeline.setup(self, items, train_setup)
#     238 tfms = self.fs[:]
#     239 self.fs.clear()
# --> 240 for t in tfms: self.add(t,items, train_setup)
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fasttransform\transform.py:244, in Pipeline.add(self, ts, items, train_setup)
#     242 def add(self,ts, items=None, train_setup=False):
#     243     if not is_listy(ts): ts=[ts]
# --> 244     for t in ts: t.setup(items, train_setup)
#     245     self.fs+=ts
#     246     self.fs = self.fs.sorted(key='order')
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fastai\tabular\core.py:226, in TabularProc.setup(self, items, train_setup)
#     225 def setup(self, items=None, train_setup=False): #TODO: properly deal with train_setup
# --> 226     super().setup(getattr(items,'train',items), train_setup=False)
#     227     # Procs are called as soon as data is available
#     228     return self(items.items if isinstance(items,Datasets) else items)
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fasttransform\transform.py:119, in Transform.setup(self, items, train_setup)
#     117 train_setup = train_setup if self.train_setup is None else self.train_setup
#     118 items = getattr(items, 'train', items) if train_setup else items
# --> 119 try: return self.setups(items)
#     120 except (AttributeError, NotFoundLookupError): return None
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\plum\function.py:509, in _BoundFunction.__call__(self, _, *args, **kw_args)
#     508 def __call__(self, _, *args, **kw_args):
# --> 509     return self._f(self._instance, *args, **kw_args)
#
#     [... skipping hidden 1 frame]
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fastai\tabular\core.py:304, in FillMissing.setups(self, to)
#     303 def setups(self, to):
# --> 304     missing = pd.isnull(to.conts).any()
#     305     store_attr(but='to', na_dict={n:self.fill_strategy(to[n], self.fill_vals[n])
#     306                         for n in missing[missing].keys()})
#     307     self.fill_strategy = self.fill_strategy.__name__
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fastai\tabular\core.py:210, in _add_prop.<locals>.f(o)
#     209 @property
# --> 210 def f(o): return o[list(getattr(o,nm+'_names'))]
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\fastcore\foundation.py:90, in CollBase.__getitem__(self, k)
# ---> 90 def __getitem__(self, k): return self.items[list(k) if isinstance(k,CollBase) else k]
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File d:\githib repo clones\house-price-prediction\venv\Lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['LogSalePrice'] not in index"
